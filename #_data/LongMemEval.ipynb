# %%
# !git clone https://github.com/xiaowu0162/LongMemEval.git
# Out:
# Cloning into 'LongMemEval'...

# %%
# %pip install -r LongMemEval/requirements-lite.txt
# Out:
# Requirement already satisfied: packaging in d:\Learning\RAG\.venv\Lib\site-packages (from -r LongMemEval/requirements-lite.txt (line 1)) (26.0)
# Collecting openai==1.35.1 (from -r LongMemEval/requirements-lite.txt (line 2))
#   Downloading openai-1.35.1-py3-none-any.whl.metadata (21 kB)
# Collecting tqdm==4.66.4 (from -r LongMemEval/requirements-lite.txt (line 3))
#   Downloading tqdm-4.66.4-py3-none-any.whl.metadata (57 kB)
# Collecting backoff==2.2.1 (from -r LongMemEval/requirements-lite.txt (line 4))
#   Using cached backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Collecting numpy==1.26.3 (from -r LongMemEval/requirements-lite.txt (line 5))
#   Using cached numpy-1.26.3.tar.gz (15.7 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): still running...
#   Preparing metadata (pyproject.toml): still running...
#   Preparing metadata (pyproject.toml): still running...
#   Preparing metadata (pyproject.toml): still running...
#   Preparing metadata (pyproject.toml): still running...
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting nltk==3.9.1 (from -r LongMemEval/requirements-lite.txt (line 6))
#   Using cached nltk-3.9.1-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in d:\Learning\RAG\.venv\Lib\site-packages (from openai==1.35.1->-r LongMemEval/requirements-lite.txt (line 2)) (4.12.1)
# Requirement already satisfied: distro<2,>=1.7.0 in d:\Learning\RAG\.venv\Lib\site-packages (from openai==1.35.1->-r LongMemEval/requirements-lite.txt (line 2)) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in d:\Learning\RAG\.venv\Lib\site-packages (from openai==1.35.1->-r LongMemEval/requirements-lite.txt (line 2)) (0.28.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in d:\Learning\RAG\.venv\Lib\site-packages (from openai==1.35.1->-r LongMemEval/requirements-lite.txt (line 2)) (2.12.5)
# Requirement already satisfied: sniffio in d:\Learning\RAG\.venv\Lib\site-packages (from openai==1.35.1->-r LongMemEval/requirements-lite.txt (line 2)) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.7 in d:\Learning\RAG\.venv\Lib\site-packages (from openai==1.35.1->-r LongMemEval/requirements-lite.txt (line 2)) (4.15.0)
# Requirement already satisfied: colorama in d:\Learning\RAG\.venv\Lib\site-packages (from tqdm==4.66.4->-r LongMemEval/requirements-lite.txt (line 3)) (0.4.6)
# Requirement already satisfied: click in d:\Learning\RAG\.venv\Lib\site-packages (from nltk==3.9.1->-r LongMemEval/requirements-lite.txt (line 6)) (8.3.1)
# Requirement already satisfied: joblib in d:\Learning\RAG\.venv\Lib\site-packages (from nltk==3.9.1->-r LongMemEval/requirements-lite.txt (line 6)) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in d:\Learning\RAG\.venv\Lib\site-packages (from nltk==3.9.1->-r LongMemEval/requirements-lite.txt (line 6)) (2026.2.28)
# Requirement already satisfied: idna>=2.8 in d:\Learning\RAG\.venv\Lib\site-packages (from anyio<5,>=3.5.0->openai==1.35.1->-r LongMemEval/requirements-lite.txt (line 2)) (3.11)
# Requirement already satisfied: certifi in d:\Learning\RAG\.venv\Lib\site-packages (from httpx<1,>=0.23.0->openai==1.35.1->-r LongMemEval/requirements-lite.txt (line 2)) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in d:\Learning\RAG\.venv\Lib\site-packages (from httpx<1,>=0.23.0->openai==1.35.1->-r LongMemEval/requirements-lite.txt (line 2)) (1.0.9)
# Requirement already satisfied: h11>=0.16 in d:\Learning\RAG\.venv\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai==1.35.1->-r LongMemEval/requirements-lite.txt (line 2)) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\Learning\RAG\.venv\Lib\site-packages (from pydantic<3,>=1.9.0->openai==1.35.1->-r LongMemEval/requirements-lite.txt (line 2)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in d:\Learning\RAG\.venv\Lib\site-packages (from pydantic<3,>=1.9.0->openai==1.35.1->-r LongMemEval/requirements-lite.txt (line 2)) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in d:\Learning\RAG\.venv\Lib\site-packages (from pydantic<3,>=1.9.0->openai==1.35.1->-r LongMemEval/requirements-lite.txt (line 2)) (0.4.2)
# Downloading openai-1.35.1-py3-none-any.whl (326 kB)
# Downloading tqdm-4.66.4-py3-none-any.whl (78 kB)
# Using cached backoff-2.2.1-py3-none-any.whl (15 kB)
# Using cached nltk-3.9.1-py3-none-any.whl (1.5 MB)
# Building wheels for collected packages: numpy
#   Building wheel for numpy (pyproject.toml): started
#   Building wheel for numpy (pyproject.toml): finished with status 'done'
#   Created wheel for numpy: filename=numpy-1.26.3-cp313-cp313-win_amd64.whl size=20524147 sha256=f6580fc6b76049a969d6625fcd19546ddcad6164b164b8e9512052a09fb33a1a
#   Stored in directory: c:\users\nilanjan.paul\appdata\local\pip\cache\wheels\cd\80\5a\8deaed51e64f65a6fa8d0bd4078495e3d242f13a65f6a627d0
# Successfully built numpy
# Installing collected packages: tqdm, numpy, backoff, nltk, openai
#
#   Attempting uninstall: tqdm
#
#     Found existing installation: tqdm 4.67.3
#
#    ---------------------------------------- 0/5 [tqdm]
#     Uninstalling tqdm-4.67.3:
#    ---------------------------------------- 0/5 [tqdm]
#    ---------------------------------------- 0/5 [tqdm]
#    ---------------------------------------- 0/5 [tqdm]
#       Successfully uninstalled tqdm-4.67.3
#    ---------------------------------------- 0/5 [tqdm]
#    ---------------------------------------- 0/5 [tqdm]
#    ---------------------------------------- 0/5 [tqdm]
#    ---------------------------------------- 0/5 [tqdm]
#    ---------------------------------------- 0/5 [tqdm]
#    ---------------------------------------- 0/5 [tqdm]
#    ---------------------------------------- 0/5 [tqdm]
#    ---------------------------------------- 0/5 [tqdm]
#    ---------------------------------------- 0/5 [tqdm]
#    ---------------------------------------- 0/5 [tqdm]
#    ---------------------------------------- 0/5 [tqdm]
#    ---------------------------------------- 0/5 [tqdm]
#    ---------------------------------------- 0/5 [tqdm]
#    ---------------------------------------- 0/5 [tqdm]
#    ---------------------------------------- 0/5 [tqdm]
#    ---------------------------------------- 0/5 [tqdm]
#    ---------------------------------------- 0/5 [tqdm]
#    ---------------------------------------- 0/5 [tqdm]
#    ---------------------------------------- 0/5 [tqdm]
#    ---------------------------------------- 0/5 [tqdm]
#    ---------------------------------------- 0/5 [tqdm]
#    ---------------------------------------- 0/5 [tqdm]
#    ---------------------------------------- 0/5 [tqdm]
#    ---------------------------------------- 0/5 [tqdm]
#    ---------------------------------------- 0/5 [tqdm]
#    ---------------------------------------- 0/5 [tqdm]
#    ---------------------------------------- 0/5 [tqdm]
#    ---------------------------------------- 0/5 [tqdm]
#    ---------------------------------------- 0/5 [tqdm]
#    ---------------------------------------- 0/5 [tqdm]
#    ---------------------------------------- 0/5 [tqdm]
#    ---------------------------------------- 0/5 [tqdm]
#    ---------------------------------------- 0/5 [tqdm]
#    ---------------------------------------- 0/5 [tqdm]
#    ---------------------------------------- 0/5 [tqdm]
#    ---------------------------------------- 0/5 [tqdm]
#    ---------------------------------------- 0/5 [tqdm]
#    ---------------------------------------- 0/5 [tqdm]
#    ---------------------------------------- 0/5 [tqdm]
#    ---------------------------------------- 0/5 [tqdm]
#    ---------------------------------------- 0/5 [tqdm]
#    ---------------------------------------- 0/5 [tqdm]
#    ---------------------------------------- 0/5 [tqdm]
#    ---------------------------------------- 0/5 [tqdm]
#    ---------------------------------------- 0/5 [tqdm]
#    ---------------------------------------- 0/5 [tqdm]
#    ---------------------------------------- 0/5 [tqdm]
#    ---------------------------------------- 0/5 [tqdm]
#    ---------------------------------------- 0/5 [tqdm]
#   Attempting uninstall: numpy
#    ---------------------------------------- 0/5 [tqdm]
#     Found existing installation: numpy 2.4.3
#    ---------------------------------------- 0/5 [tqdm]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#     Uninstalling numpy-2.4.3:
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#       Successfully uninstalled numpy-2.4.3
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    ---------------- ----------------------- 2/5 [backoff]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#   Attempting uninstall: openai
#    ------------------------ --------------- 3/5 [nltk]
#     Found existing installation: openai 2.29.0
#    ------------------------ --------------- 3/5 [nltk]
#    -------------------------------- ------- 4/5 [openai]
#    -------------------------------- ------- 4/5 [openai]
#    -------------------------------- ------- 4/5 [openai]
#    -------------------------------- ------- 4/5 [openai]
#    -------------------------------- ------- 4/5 [openai]
#     Uninstalling openai-2.29.0:
#    -------------------------------- ------- 4/5 [openai]
#       Successfully uninstalled openai-2.29.0
#    -------------------------------- ------- 4/5 [openai]
#    -------------------------------- ------- 4/5 [openai]
#    -------------------------------- ------- 4/5 [openai]
#    -------------------------------- ------- 4/5 [openai]
#    -------------------------------- ------- 4/5 [openai]
#    -------------------------------- ------- 4/5 [openai]
#    -------------------------------- ------- 4/5 [openai]
#    -------------------------------- ------- 4/5 [openai]
#    -------------------------------- ------- 4/5 [openai]
#    -------------------------------- ------- 4/5 [openai]
#    -------------------------------- ------- 4/5 [openai]
#    -------------------------------- ------- 4/5 [openai]
#    -------------------------------- ------- 4/5 [openai]
#    -------------------------------- ------- 4/5 [openai]
#    -------------------------------- ------- 4/5 [openai]
#    -------------------------------- ------- 4/5 [openai]
#    -------------------------------- ------- 4/5 [openai]
#    -------------------------------- ------- 4/5 [openai]
#    -------------------------------- ------- 4/5 [openai]
#    -------------------------------- ------- 4/5 [openai]
#    -------------------------------- ------- 4/5 [openai]
#    -------------------------------- ------- 4/5 [openai]
#    -------------------------------- ------- 4/5 [openai]
#    -------------------------------- ------- 4/5 [openai]
#    -------------------------------- ------- 4/5 [openai]
#    -------------------------------- ------- 4/5 [openai]
#    -------------------------------- ------- 4/5 [openai]
#    -------------------------------- ------- 4/5 [openai]
#    -------------------------------- ------- 4/5 [openai]
#    -------------------------------- ------- 4/5 [openai]
#    -------------------------------- ------- 4/5 [openai]
#    -------------------------------- ------- 4/5 [openai]
#    ---------------------------------------- 5/5 [openai]
#
# Successfully installed backoff-2.2.1 nltk-3.9.1 numpy-1.26.3 openai-1.35.1 tqdm-4.66.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langchain-community 0.4.1 requires numpy>=2.1.0; python_version >= "3.13", but you have numpy 1.26.3 which is incompatible.
# langchain-openai 1.1.11 requires openai<3.0.0,>=2.26.0, but you have openai 1.35.1 which is incompatible.
# ml-dtypes 0.5.4 requires numpy>=2.1.0; python_version >= "3.13", but you have numpy 1.26.3 which is incompatible.
# nncf 3.0.0 requires networkx<3.5.0,>=2.6, but you have networkx 3.6.1 which is incompatible.
# scipy 1.17.1 requires numpy<2.7,>=1.26.4, but you have numpy 1.26.3 which is incompatible.
# Requirement already satisfied: packaging in d:\Learning\RAG\.venv\Lib\site-packages (from -r LongMemEval/requirements-lite.txt (line 1)) (26.0)
# Collecting openai==1.35.1 (from -r LongMemEval/requirements-lite.txt (line 2))
#   Using cached openai-1.35.1-py3-none-any.whl.metadata (21 kB)
# Collecting tqdm==4.66.4 (from -r LongMemEval/requirements-lite.txt (line 3))
#   Using cached tqdm-4.66.4-py3-none-any.whl.metadata (57 kB)
# Collecting backoff==2.2.1 (from -r LongMemEval/requirements-lite.txt (line 4))
#   Using cached backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Collecting numpy==1.26.3 (from -r LongMemEval/requirements-lite.txt (line 5))
#   Using cached numpy-1.26.3.tar.gz (15.7 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): still running...
#   Preparing metadata (pyproject.toml): still running...
#   Preparing metadata (pyproject.toml): still running...
#   Preparing metadata (pyproject.toml): still running...
#   Preparing metadata (pyproject.toml): still running...
#   Preparing metadata (pyproject.toml): still running...
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting nltk==3.9.1 (from -r LongMemEval/requirements-lite.txt (line 6))
#   Using cached nltk-3.9.1-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in d:\Learning\RAG\.venv\Lib\site-packages (from openai==1.35.1->-r LongMemEval/requirements-lite.txt (line 2)) (4.12.1)
# Requirement already satisfied: distro<2,>=1.7.0 in d:\Learning\RAG\.venv\Lib\site-packages (from openai==1.35.1->-r LongMemEval/requirements-lite.txt (line 2)) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in d:\Learning\RAG\.venv\Lib\site-packages (from openai==1.35.1->-r LongMemEval/requirements-lite.txt (line 2)) (0.28.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in d:\Learning\RAG\.venv\Lib\site-packages (from openai==1.35.1->-r LongMemEval/requirements-lite.txt (line 2)) (2.12.5)
# Requirement already satisfied: sniffio in d:\Learning\RAG\.venv\Lib\site-packages (from openai==1.35.1->-r LongMemEval/requirements-lite.txt (line 2)) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.7 in d:\Learning\RAG\.venv\Lib\site-packages (from openai==1.35.1->-r LongMemEval/requirements-lite.txt (line 2)) (4.15.0)
# Requirement already satisfied: colorama in d:\Learning\RAG\.venv\Lib\site-packages (from tqdm==4.66.4->-r LongMemEval/requirements-lite.txt (line 3)) (0.4.6)
# Requirement already satisfied: click in d:\Learning\RAG\.venv\Lib\site-packages (from nltk==3.9.1->-r LongMemEval/requirements-lite.txt (line 6)) (8.3.1)
# Requirement already satisfied: joblib in d:\Learning\RAG\.venv\Lib\site-packages (from nltk==3.9.1->-r LongMemEval/requirements-lite.txt (line 6)) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in d:\Learning\RAG\.venv\Lib\site-packages (from nltk==3.9.1->-r LongMemEval/requirements-lite.txt (line 6)) (2026.2.28)
# Requirement already satisfied: idna>=2.8 in d:\Learning\RAG\.venv\Lib\site-packages (from anyio<5,>=3.5.0->openai==1.35.1->-r LongMemEval/requirements-lite.txt (line 2)) (3.11)
# Requirement already satisfied: certifi in d:\Learning\RAG\.venv\Lib\site-packages (from httpx<1,>=0.23.0->openai==1.35.1->-r LongMemEval/requirements-lite.txt (line 2)) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in d:\Learning\RAG\.venv\Lib\site-packages (from httpx<1,>=0.23.0->openai==1.35.1->-r LongMemEval/requirements-lite.txt (line 2)) (1.0.9)
# Requirement already satisfied: h11>=0.16 in d:\Learning\RAG\.venv\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai==1.35.1->-r LongMemEval/requirements-lite.txt (line 2)) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\Learning\RAG\.venv\Lib\site-packages (from pydantic<3,>=1.9.0->openai==1.35.1->-r LongMemEval/requirements-lite.txt (line 2)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in d:\Learning\RAG\.venv\Lib\site-packages (from pydantic<3,>=1.9.0->openai==1.35.1->-r LongMemEval/requirements-lite.txt (line 2)) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in d:\Learning\RAG\.venv\Lib\site-packages (from pydantic<3,>=1.9.0->openai==1.35.1->-r LongMemEval/requirements-lite.txt (line 2)) (0.4.2)
# Using cached openai-1.35.1-py3-none-any.whl (326 kB)
# Using cached tqdm-4.66.4-py3-none-any.whl (78 kB)
# Using cached backoff-2.2.1-py3-none-any.whl (15 kB)
# Using cached nltk-3.9.1-py3-none-any.whl (1.5 MB)
# Building wheels for collected packages: numpy
#   Building wheel for numpy (pyproject.toml): started
#   Building wheel for numpy (pyproject.toml): finished with status 'done'
#   Created wheel for numpy: filename=numpy-1.26.3-cp313-cp313-win_amd64.whl size=20524147 sha256=cd1cf4a61a2f89986fb9b4a894cc1012a331faf9f2b93b3d8724326a2dd284c8
#   Stored in directory: c:\users\nilanjan.paul\appdata\local\pip\cache\wheels\cd\80\5a\8deaed51e64f65a6fa8d0bd4078495e3d242f13a65f6a627d0
# Successfully built numpy
# Installing collected packages: tqdm, numpy, backoff, nltk, openai
#
#   Attempting uninstall: tqdm
#
#     Found existing installation: tqdm 4.66.4
#
#     Uninstalling tqdm-4.66.4:
#
#       Successfully uninstalled tqdm-4.66.4
#
#    ---------------------------------------- 0/5 [tqdm]
#    ---------------------------------------- 0/5 [tqdm]
#    ---------------------------------------- 0/5 [tqdm]
#    ---------------------------------------- 0/5 [tqdm]
#   Attempting uninstall: numpy
#    ---------------------------------------- 0/5 [tqdm]
#     Found existing installation: numpy 1.26.3
#    ---------------------------------------- 0/5 [tqdm]
#    -------- ------------------------------- 1/5 [numpy]
#     Uninstalling numpy-1.26.3:
#    -------- ------------------------------- 1/5 [numpy]
#       Successfully uninstalled numpy-1.26.3
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    ---------------- ----------------------- 2/5 [backoff]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#    ------------------------ --------------- 3/5 [nltk]
#   Attempting uninstall: openai
#    ------------------------ --------------- 3/5 [nltk]
#     Found existing installation: openai 1.35.1
#    ------------------------ --------------- 3/5 [nltk]
#    -------------------------------- ------- 4/5 [openai]
#     Uninstalling openai-1.35.1:
#    -------------------------------- ------- 4/5 [openai]
#       Successfully uninstalled openai-1.35.1
#    -------------------------------- ------- 4/5 [openai]
#    -------------------------------- ------- 4/5 [openai]
#    -------------------------------- ------- 4/5 [openai]
#    -------------------------------- ------- 4/5 [openai]
#    -------------------------------- ------- 4/5 [openai]
#    -------------------------------- ------- 4/5 [openai]
#    -------------------------------- ------- 4/5 [openai]
#    -------------------------------- ------- 4/5 [openai]
#    -------------------------------- ------- 4/5 [openai]
#    -------------------------------- ------- 4/5 [openai]
#    -------------------------------- ------- 4/5 [openai]
#    -------------------------------- ------- 4/5 [openai]
#    -------------------------------- ------- 4/5 [openai]
#    -------------------------------- ------- 4/5 [openai]
#    -------------------------------- ------- 4/5 [openai]
#    -------------------------------- ------- 4/5 [openai]
#    -------------------------------- ------- 4/5 [openai]
#    -------------------------------- ------- 4/5 [openai]
#    -------------------------------- ------- 4/5 [openai]
#    -------------------------------- ------- 4/5 [openai]
#    -------------------------------- ------- 4/5 [openai]
#    ---------------------------------------- 5/5 [openai]
#
# Successfully installed backoff-2.2.1 nltk-3.9.1 numpy-1.26.3 openai-1.35.1 tqdm-4.66.4
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langchain-community 0.4.1 requires numpy>=2.1.0; python_version >= "3.13", but you have numpy 1.26.3 which is incompatible.
# langchain-openai 1.1.11 requires openai<3.0.0,>=2.26.0, but you have openai 1.35.1 which is incompatible.
# ml-dtypes 0.5.4 requires numpy>=2.1.0; python_version >= "3.13", but you have numpy 1.26.3 which is incompatible.
# nncf 3.0.0 requires networkx<3.5.0,>=2.6, but you have networkx 3.6.1 which is incompatible.
# scipy 1.17.1 requires numpy<2.7,>=1.26.4, but you have numpy 1.26.3 which is incompatible.

# %%
# %wget -P LongMemEval/data https://huggingface.co/datasets/xiaowu0162/longmemeval-cleaned/resolve/main/longmemeval_s.json
# Out:
# UsageError: Line magic function `%wget` not found.

# %%
# Step 2: Prepare a subset of the dataset with 10 entries
import json
import os

# Load the dataset
dataset_path = 'LongMemEval/data/longmemeval_s_cleaned.json'
subset_path = 'LongMemEval/data/longmemeval_subset.json'

if not os.path.exists(dataset_path):
    raise FileNotFoundError(f"Dataset not found at {dataset_path}. Please ensure the dataset is downloaded.")

# Extract 10 entries
with open(dataset_path, 'r', encoding='utf-8') as f:  # Specify UTF-8 encoding
    data = json.load(f)
subset = data[:10]  # Take the first 10 entries

# Save the subset
with open(subset_path, 'w', encoding='utf-8') as f:  # Specify UTF-8 encoding
    json.dump(subset, f, indent=4)
print(f"Subset saved to {subset_path}")
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[5], line 17
#      15 # Extract 10 entries
#      16 with open(dataset_path, 'r') as f:
# ---> 17     data = json.load(f)
#      18 subset = data[:10]  # Take the first 10 entries
#      20 # Save the subset
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\json\__init__.py:293, in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     274 def load(fp, *, cls=None, object_hook=None, parse_float=None,
#     275         parse_int=None, parse_constant=None, object_pairs_hook=None, **kw):
#     276     """Deserialize ``fp`` (a ``.read()``-supporting file-like object containing
#     277     a JSON document) to a Python object.
#     278
#    (...)    291     kwarg; otherwise ``JSONDecoder`` is used.
#     292     """
# --> 293     return loads(fp.read(),
#     294         cls=cls, object_hook=object_hook,
#     295         parse_float=parse_float, parse_int=parse_int,
#     296         parse_constant=parse_constant, object_pairs_hook=object_pairs_hook, **kw)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\encodings\cp1252.py:23, in IncrementalDecoder.decode(self, input, final)
#      22 def decode(self, input, final=False):
# ---> 23     return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x81 in position 107102: character maps to <undefined>
